# %% [markdown]
# # Change Impact Evaluation
# Run sample change requests through deterministic impact logic.

# %%
from app.services.graph_loader import GraphLoader
from app.services.impact_engine import ImpactEngine
g = GraphLoader().load()
ImpactEngine().impacted_nodes(g, 'auth-service')[:10]
